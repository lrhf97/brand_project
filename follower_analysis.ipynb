# %%
import pandas as pd

# %%
# Grab the list of the followers 
df =  pd.read_csv("data/rs_fr_list.csv")
df.head()
# Out:
#                     id                 created_at location  \
# 0  1462051017999233030  2021-11-20 13:32:06+00:00
# 1           2365799779  2014-02-28 15:49:49+00:00
# 2           3386288339  2015-07-21 20:02:19+00:00
# 3             33535739  2009-04-20 14:52:11+00:00
# 4  1418283365577461764  2021-07-22 18:55:59+00:00
#
#                                          description         username  \
# 0                                           Brew Man   jesse_prall_76
# 1                                   Simpsons did it.  _stackshotbilly
# 2  Husband, dad, cyclist, InfoSec Professional an...       JMoney_724
# 3  Coowner of @moonlight_speed - trying to drive ...         jspoon13
# 4  Fitness, Fellowship, & Faith coming to Morgant...      f3morganton
#
#              name verified followers_count following_count tweet_count  \
# 0     Jesse Prall    False               0              20           0
# 1  stackshotbilly    False              35             403         322
# 2               J    False              47             352         321
# 3    Jordan Spoon    False             133             709         401
# 4     f3morganton    False              23              78           2
#
#   listed_count
# 0            0
# 1            0
# 2            8
# 3            0
# 4            0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672 entries, 0 to 671
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               672 non-null    object
#  1   created_at       672 non-null    object
#  2   location         672 non-null    object
#  3   description      542 non-null    object
#  4   username         672 non-null    object
#  5   name             672 non-null    object
#  6   verified         672 non-null    object
#  7   followers_count  672 non-null    object
#  8   following_count  672 non-null    object
#  9   tweet_count      672 non-null    object
#  10  listed_count     672 non-null    object
# dtypes: object(11)
# memory usage: 57.9+ KB

# %%
df.describe()
# Out:
#                id                 created_at location  \
# count         672                        672      672
# unique        360                        360        2
# top     135706106  2018-01-08 17:00:42+00:00
# freq            2                          2      671
#
#                                        description    username     name  \
# count                                          542         672      672
# unique                                         317         360      371
# top     Fontanero freelance. Nos comen los chinos.  memochucho  Big Ben
# freq                                             2           2        2
#
#        verified followers_count following_count tweet_count listed_count
# count       672             672             672         672          672
# unique        3             417             532         529          101
# top       False               0              64           1            0
# freq        669              10               6          10          167

# %%
# Create a Ratio column
df['ratio'] = round(df['followers_count']/df['following_count'],2)
df[df['followers_count'] == df['followers_count'].max()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:142, in _na_arithmetic_op(left, right, op, is_cmp)
#     141 try:
# --> 142     result = expressions.evaluate(op, left, right)
#     143 except TypeError:
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:235, in evaluate(op, a, b, use_numexpr)
#     233     if use_numexpr:
#     234         # error: "None" not callable
# --> 235         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     236 return _evaluate_standard(op, op_str, a, b)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:69, in _evaluate_standard(op, op_str, a, b)
#      68 with np.errstate(all="ignore"):
# ---> 69     return op(a, b)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /home/awstclair/github_forks/brand_project/follower_analysis.ipynb Cell 5' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/awstclair/github_forks/brand_project/follower_analysis.ipynb#ch0000004?line=0'>1</a> # Create a Ratio column
# ----> <a href='vscode-notebook-cell:/home/awstclair/github_forks/brand_project/follower_analysis.ipynb#ch0000004?line=1'>2</a> df['ratio'] = round(df['followers_count']/df['following_count'],2)
#       <a href='vscode-notebook-cell:/home/awstclair/github_forks/brand_project/follower_analysis.ipynb#ch0000004?line=2'>3</a> df[df['followers_count'] == df['followers_count'].max()]
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/ops/common.py:65, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      61             return NotImplemented
#      63 other = item_from_zerodim(other)
# ---> 65 return method(self, other)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:113, in OpsMixin.__truediv__(self, other)
#     111 @unpack_zerodim_and_defer("__truediv__")
#     112 def __truediv__(self, other):
# --> 113     return self._arith_method(other, operator.truediv)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/series.py:4998, in Series._arith_method(self, other, op)
#    4996 lvalues = extract_array(self, extract_numpy=True)
#    4997 rvalues = extract_array(other, extract_numpy=True)
# -> 4998 result = ops.arithmetic_op(lvalues, rvalues, op)
#    5000 return self._construct_result(result, name=res_name)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:189, in arithmetic_op(left, right, op)
#     187 else:
#     188     with np.errstate(all="ignore"):
# --> 189         res_values = _na_arithmetic_op(lvalues, rvalues, op)
#     191 return res_values
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:149, in _na_arithmetic_op(left, right, op, is_cmp)
#     144     if is_cmp:
#     145         # numexpr failed on comparison op, e.g. ndarray[float] > datetime
#     146         #  In this case we do not fall back to the masked op, as that
#     147         #  will handle complex numbers incorrectly, see GH#32047
#     148         raise
# --> 149     result = _masked_arith_op(left, right, op)
#     151 if is_cmp and (is_scalar(result) or result is NotImplemented):
#     152     # numpy returned a scalar instead of operating element-wise
#     153     # e.g. numeric array vs str
#     154     return invalid_comparison(left, right, op)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:91, in _masked_arith_op(x, y, op)
#      89     if mask.any():
#      90         with np.errstate(all="ignore"):
# ---> 91             result[mask] = op(xrav[mask], yrav[mask])
#      93 else:
#      94     if not is_scalar(y):
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
df[df['tweet_count'] == df['tweet_count'].max()]['description'].values
# Out:
# array(['description'], dtype=object)

# %%
df[['id','username','name','location']].head()
# Out:
#                     id         username            name location
# 0  1462051017999233030   jesse_prall_76     Jesse Prall
# 1           2365799779  _stackshotbilly  stackshotbilly
# 2           3386288339       JMoney_724               J
# 3             33535739         jspoon13    Jordan Spoon
# 4  1418283365577461764      f3morganton     f3morganton

# %%
df.sort_values('listed_count', ascending= False).head(5)
# Out:
#            id                 created_at  location  \
# 321        id                 created_at  location
# 17   20662440  2009-02-12 08:36:48+00:00
# 376  20662440  2009-02-12 08:36:48+00:00
# 414  66628997  2009-08-18 08:08:42+00:00
# 55   66628997  2009-08-18 08:08:42+00:00
#
#                                            description       username  \
# 321                                        description       username
# 17   Bike nomad, boycotting fossil-fuels, rewilding...   philsturgeon
# 376  Bike nomad, boycotting fossil-fuels, rewilding...   philsturgeon
# 414          Agent, Lawyer, Husband, Father, Dog Owner  andrewmcquaid
# 55           Agent, Lawyer, Husband, Father, Dog Owner  andrewmcquaid
#
#                           name  verified  followers_count  following_count  \
# 321                       name  verified  followers_count  following_count
# 17   Wandering Woodsman 🔥🚴‍♂️🌳     False            22415             2908
# 376     Wandering Woodsman 🚴🔥🌍     False            22575             3083
# 414             Andrew McQuaid     False             5002             3986
# 55              Andrew McQuaid     False             5012             3944
#
#      tweet_count  listed_count
# 321  tweet_count  listed_count
# 17         70597           995
# 376        72925           986
# 414         4119            91
# 55          4108            90

# %%
top5followers = df.sort_values('followers_count', ascending= False).head(5)[['id','username','name']]
top5followers.to_csv('data/top5followers.csv')
top5followers
# Out:
#              id      username           name
# 321          id      username           name
# 358    27364191  CrossSportif  Geoff Proctor
# 487    21147500      rogersta    Drew Rogers
# 460    15469732  rickcrawford  Rick Crawford
# 172  2825654053  mike_boudrie   Mike Boudrie

# %%
name = df[df['id'] == id]['name']

# %%
df.sort_values('ratio', ascending= False).head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/awstclair/github_forks/brand_project/follower_analysis.ipynb Cell 11' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/awstclair/github_forks/brand_project/follower_analysis.ipynb#ch0000010?line=0'>1</a> df.sort_values('ratio', ascending= False).head(5)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:5455, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5452 else:
#    5454     by = by[0]
# -> 5455     k = self._get_label_or_level_values(by, axis=axis)
#    5457     # need to rewrap column in Series to apply key function
#    5458     if key is not None:
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py:1684, in NDFrame._get_label_or_level_values(self, key, axis)
#    1682     values = self.axes[axis].get_level_values(key)._values
#    1683 else:
# -> 1684     raise KeyError(key)
#    1686 # Check for duplicates
#    1687 if values.ndim > 1:
#
# KeyError: 'ratio'

# %%
name = 'bigdog'
csv_to_file = "data/"+name+"_fr_list.csv"
csv_to_file
# Out:
# 'data/bigdog_fr_list.csv'

# %%
id = 23695888
name = top5followers[top5followers['id'] == id]['name'].values[0]
name
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/awstclair/github_forks/brand_project/follower_analysis.ipynb Cell 13' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/awstclair/github_forks/brand_project/follower_analysis.ipynb#ch0000012?line=0'>1</a> id = 23695888
# ----> <a href='vscode-notebook-cell:/home/awstclair/github_forks/brand_project/follower_analysis.ipynb#ch0000012?line=1'>2</a> name = top5followers[top5followers['id'] == id]['name'].values[0]
#       <a href='vscode-notebook-cell:/home/awstclair/github_forks/brand_project/follower_analysis.ipynb#ch0000012?line=2'>3</a> name
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
