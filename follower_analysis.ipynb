# %%
import pandas as pd

# %%
df =  pd.read_csv("data/rs_fr_list.csv")
df.head()
# Out:
#                     id                 created_at location  \
# 0  1462051017999233030  2021-11-20 13:32:06+00:00
# 1           2365799779  2014-02-28 15:49:49+00:00
# 2           3386288339  2015-07-21 20:02:19+00:00
# 3             33535739  2009-04-20 14:52:11+00:00
# 4  1418283365577461764  2021-07-22 18:55:59+00:00
#
#                                          description         username  \
# 0                                           Brew Man   jesse_prall_76
# 1                                   Simpsons did it.  _stackshotbilly
# 2  Husband, dad, cyclist, InfoSec Professional an...       JMoney_724
# 3  Coowner of @moonlight_speed - trying to drive ...         jspoon13
# 4  Fitness, Fellowship, & Faith coming to Morgant...      f3morganton
#
#              name  verified  followers_count  following_count  tweet_count  \
# 0     Jesse Prall     False                0               20            0
# 1  stackshotbilly     False               35              403          322
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               321 non-null    int64
#  1   created_at       321 non-null    object
#  2   location         321 non-null    object
#  3   description      258 non-null    object
#  4   username         321 non-null    object
#  5   name             321 non-null    object
#  6   verified         321 non-null    bool
#  7   followers_count  321 non-null    int64
#  8   following_count  321 non-null    int64
#  9   tweet_count      321 non-null    int64
#  10  listed_count     321 non-null    int64
# dtypes: bool(1), int64(5), object(5)
# memory usage: 25.5+ KB

# %%
df.describe()
# Out:
#                  id  followers_count  following_count    tweet_count  \
# count  3.210000e+02       321.000000       321.000000     321.000000
# mean   1.322882e+17      1102.211838      1153.037383    6573.124611
# std    3.419146e+17      3538.031894      1555.325576   14168.999043
# min    1.298000e+03         0.000000         8.000000       0.000000
# 25%    5.332222e+07        59.000000       255.000000     224.000000
# 50%    2.759351e+08       207.000000       645.000000    1621.000000
# 75%    2.472893e+09       521.000000      1344.000000    5892.000000
# max    1.462051e+18     32098.000000     16562.000000  136280.000000
#
#        listed_count
# count    321.000000
# mean      33.912773
# std      118.782674
# min        0.000000
# 25%        1.000000
# 50%        4.000000
# 75%       14.000000
# max     1424.000000

# %%
df[df['followers_count'] == df['followers_count'].max()]
# Out:
#            id                 created_at location  \
# 265  23695888  2009-03-11 01:07:24+00:00
#
#                                            description    username      name  \
# 265  I rock the party that rocks the piñata. Repres...  iamtedking  Ted King
#
#      verified  followers_count  following_count  tweet_count  listed_count
# 265      True            32098              900        15845          1424
